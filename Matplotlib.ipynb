# %% [markdown]
# <a href="https://colab.research.google.com/github/s65021965/Python-project/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.27453471, 0.77595964, 0.64388837, 0.3470429 , 0.9176255 ,
#        0.81055998, 0.1386427 , 0.07954347, 0.86310551, 0.63072064,
#        0.80610417, 0.90198215, 0.78469116, 0.37069982, 0.74564617,
#        0.76144356, 0.44115449, 0.70868888, 0.67797115, 0.60518415,
#        0.33278861, 0.01587143, 0.44271506, 0.90220059, 0.22283221,
#        0.91826821, 0.02016639, 0.16248009, 0.66804824, 0.60333255,
#        0.57919819, 0.17942728, 0.26655729, 0.88960854, 0.16051023,
#        0.3139687 , 0.00857127, 0.26305073, 0.10796718, 0.10130694,
#        0.82992044, 0.031682  , 0.16998477, 0.04165597, 0.17403775,
#        0.32617486, 0.66284209, 0.62325318, 0.77777408, 0.83028427])

# %%
pd.date_range('2024-05-04', periods = 1000)
# Out:
# DatetimeIndex(['2024-05-04', '2024-05-05', '2024-05-06', '2024-05-07',
#                '2024-05-08', '2024-05-09', '2024-05-10', '2024-05-11',
#                '2024-05-12', '2024-05-13',
#                ...
#                '2027-01-19', '2027-01-20', '2027-01-21', '2027-01-22',
#                '2027-01-23', '2027-01-24', '2027-01-25', '2027-01-26',
#                '2027-01-27', '2027-01-28'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
df = pd.DataFrame(pd.date_range('2024-05-04', periods = 1000))

# %%
df
# Out:
#              0
# 0   2024-05-04
# 1   2024-05-05
# 2   2024-05-06
# 3   2024-05-07
# 4   2024-05-08
# ..         ...
# 995 2027-01-24
# 996 2027-01-25
# 997 2027-01-26
# 998 2027-01-27
# 999 2027-01-28
#
# [1000 rows x 1 columns]

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y)

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x, y, marker = 'o', linestyle = '-', color = 'b', linewidth = '3')

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x, y, marker = 'o', linestyle = '-', color = 'b', linewidth = '3')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title("Line Chart")
plt.grid(True)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]
y2 = [1, 2, 3, 4, 5]

plt.plot(x, y1, label = 'Line 1')
plt.plot(x, y2, label = 'Line 2')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Two Lines Graph')
plt.legend()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 7, 11]
y2 = [1, 2, 3, 4, 5]

plt.plot(x, y1, label = 'Line 1')
plt.plot(x, y2, label = 'Line 2')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Two Lines Graph')
plt.legend()
plt.axis('equal')
plt.show()

# %%
data = np.random.randn(1000)   # Histogram is used for continuous numerical data distribution
plt.hist(data, bins = 30, edgecolor = 'black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
# Pie Chart
Students = ['Amit', 'Mohan', 'Shyam', 'Ramu']
Courses = [5, 3, 4, 1]
plt.pie(Courses, labels = Students, autopct = '%1.1f%%', startangle = 140)
plt.axis('equal')
plt.show()
